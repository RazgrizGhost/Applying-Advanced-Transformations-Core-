# %%
# Imports
import numpy as np
import pandas as pd
import ast

# Import OS and JSON 
import os,json

# %%
superdf = pd.read_csv("Data/superhero_info - superhero_info.csv")
display(superdf)
superdf.info()
# Out:
#                     Hero|Publisher  Gender               Race Alignment  \
# 0             A-Bomb|Marvel Comics    Male              Human      good
# 1     Abe Sapien|Dark Horse Comics    Male      Icthyo Sapien      good
# 2               Abin Sur|DC Comics    Male            Ungaran      good
# 3        Abomination|Marvel Comics    Male  Human / Radiation       bad
# 4      Absorbing Man|Marvel Comics    Male              Human       bad
# ..                             ...     ...                ...       ...
# 458     Yellowjacket|Marvel Comics    Male              Human      good
# 459  Yellowjacket II|Marvel Comics  Female              Human      good
# 460              Yoda|George Lucas    Male     Yoda's species      good
# 461              Zatanna|DC Comics  Female              Human      good
# 462                 Zoom|DC Comics    Male            Unknown       bad
#
#            Hair color Eye color Skin color  \
# 0             No Hair    yellow    Unknown
# ...

# %%
superpowerdf = pd.read_csv("Data/superhero_powers - superhero_powers.csv")
display(superpowerdf)
superpowerdf.info()
# Out:
#           hero_names                                             Powers
# 0            3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1             A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2         Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3           Abin Sur                                 Lantern Power Ring
# 4        Abomination  Accelerated Healing,Intelligence,Super Strengt...
# ..               ...                                                ...
# 662  Yellowjacket II                 Flight,Energy Blasts,Size Changing
# 663             Ymir  Cold Resistance,Durability,Longevity,Super Str...
# 664             Yoda  Agility,Stealth,Danger Sense,Marksmanship,Weap...
# 665          Zatanna  Cryokinesis,Telepathy,Magic,Fire Control,Proba...
# 666             Zoom  Super Speed,Intangibility,Time Travel,Time Man...
#
# [667 rows x 2 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# ...

# %%
superdf["Hero|Publisher"].value_counts()
# Out:
# Spider-Man|Marvel Comics       3
# Black Canary|DC Comics         2
# Nova|Marvel Comics             2
# Toxin|Marvel Comics            2
# Batman|DC Comics               2
#                               ..
# Fabian Cortez|Marvel Comics    1
# Exodus|Marvel Comics           1
# Evilhawk|Marvel Comics         1
# Evil Deadpool|Marvel Comics    1
# Zoom|DC Comics                 1
# Name: Hero|Publisher, Length: 457, dtype: int64

# %%
superdf["Hero|Publisher"].str.split('|', expand = True)
# Out:
#                    0                  1
# 0             A-Bomb      Marvel Comics
# 1         Abe Sapien  Dark Horse Comics
# 2           Abin Sur          DC Comics
# 3        Abomination      Marvel Comics
# 4      Absorbing Man      Marvel Comics
# ..               ...                ...
# 458     Yellowjacket      Marvel Comics
# 459  Yellowjacket II      Marvel Comics
# 460             Yoda       George Lucas
# 461          Zatanna          DC Comics
# 462             Zoom          DC Comics
#
# [463 rows x 2 columns]

# %%
# Seperated the Hero|Publisher Column into two different columns

superdf[["Hero", "Publisher"]] = superdf["Hero|Publisher"].str.split('|', expand = True)
superdf = superdf.drop(columns = "Hero|Publisher")
superdf
# Out:
#      Gender               Race Alignment        Hair color Eye color  \
# 0      Male              Human      good           No Hair    yellow
# 1      Male      Icthyo Sapien      good           No Hair      blue
# 2      Male            Ungaran      good           No Hair      blue
# 3      Male  Human / Radiation       bad           No Hair     green
# 4      Male              Human       bad           No Hair      blue
# ..      ...                ...       ...               ...       ...
# 458    Male              Human      good             Blond      blue
# 459  Female              Human      good  Strawberry Blond      blue
# 460    Male     Yoda's species      good             White     brown
# 461  Female              Human      good             Black      blue
# 462    Male            Unknown       bad             Brown       red
#
#     Skin color                                  Measurements             Hero  \
# ...

# %%
# replacing all single quotes for json.loads
superdf["Measurements"] = superdf["Measurements"].str.replace("'",'"')

# applying json.loads for the whole column
superdf["Measurements"] = superdf["Measurements"].apply(json.loads)
superdf["Measurements"]
# Out:
# 0      {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1       {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2       {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3      {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4      {'Height': '193.0 cm', 'Weight': '122.0 kg'}
#                            ...
# 458     {'Height': '183.0 cm', 'Weight': '83.0 kg'}
# 459     {'Height': '165.0 cm', 'Weight': '52.0 kg'}
# 460      {'Height': '66.0 cm', 'Weight': '17.0 kg'}
# 461     {'Height': '170.0 cm', 'Weight': '57.0 kg'}
# 462     {'Height': '185.0 cm', 'Weight': '81.0 kg'}
# Name: Measurements, Length: 463, dtype: object

# %%
# making the columns for Height and Weight
h_w = superdf["Measurements"].apply(pd.Series)
h_w
# Out:
#        Height    Weight
# 0    203.0 cm  441.0 kg
# 1    191.0 cm   65.0 kg
# 2    185.0 cm   90.0 kg
# 3    203.0 cm  441.0 kg
# 4    193.0 cm  122.0 kg
# ..        ...       ...
# 458  183.0 cm   83.0 kg
# 459  165.0 cm   52.0 kg
# 460   66.0 cm   17.0 kg
# 461  170.0 cm   57.0 kg
# 462  185.0 cm   81.0 kg
#
# [463 rows x 2 columns]

# %%
# combining it with the main DataFrame
superdf = pd.concat((superdf, h_w), axis = 1)
superdf = superdf.drop(columns = "Measurements")
superdf
# Out:
#      Gender               Race Alignment        Hair color Eye color  \
# 0      Male              Human      good           No Hair    yellow
# 1      Male      Icthyo Sapien      good           No Hair      blue
# 2      Male            Ungaran      good           No Hair      blue
# 3      Male  Human / Radiation       bad           No Hair     green
# 4      Male              Human       bad           No Hair      blue
# ..      ...                ...       ...               ...       ...
# 458    Male              Human      good             Blond      blue
# 459  Female              Human      good  Strawberry Blond      blue
# 460    Male     Yoda's species      good             White     brown
# 461  Female              Human      good             Black      blue
# 462    Male            Unknown       bad             Brown       red
#
#     Skin color             Hero          Publisher    Height    Weight
# ...

# %%
superpowerdf["Powers_Split"] = superpowerdf["Powers"].str.split(",") 
superpowerdf["Powers_Split"]
# Out:
# 0        [Agility, Super Strength, Stamina, Super Speed]
# 1      [Accelerated Healing, Durability, Longevity, S...
# 2      [Agility, Accelerated Healing, Cold Resistance...
# 3                                   [Lantern Power Ring]
# 4      [Accelerated Healing, Intelligence, Super Stre...
#                              ...
# 662               [Flight, Energy Blasts, Size Changing]
# 663    [Cold Resistance, Durability, Longevity, Super...
# 664    [Agility, Stealth, Danger Sense, Marksmanship,...
# 665    [Cryokinesis, Telepathy, Magic, Fire Control, ...
# 666    [Super Speed, Intangibility, Time Travel, Time...
# Name: Powers_Split, Length: 667, dtype: object

# %%
exploded = superpowerdf.explode("Powers_Split")
exploded[["hero_names", "Powers_Split"]]
# Out:
#     hero_names         Powers_Split
# 0      3-D Man              Agility
# 0      3-D Man       Super Strength
# 0      3-D Man              Stamina
# 0      3-D Man          Super Speed
# 1       A-Bomb  Accelerated Healing
# ..         ...                  ...
# 665    Zatanna      Weather Control
# 666       Zoom          Super Speed
# 666       Zoom        Intangibility
# 666       Zoom          Time Travel
# 666       Zoom    Time Manipulation
#
# [5874 rows x 2 columns]

# %%
cols_to_make = exploded["Powers_Split"].dropna().unique()
cols_to_make
# Out:
# array(['Agility', 'Super Strength', 'Stamina', 'Super Speed',
#        'Accelerated Healing', 'Durability', 'Longevity', 'Camouflage',
#        'Self-Sustenance', 'Cold Resistance', 'Underwater breathing',
#        'Marksmanship', 'Weapons Master', 'Intelligence', 'Telepathy',
#        'Immortality', 'Reflexes', 'Enhanced Sight', 'Sub-Mariner',
#        'Lantern Power Ring', 'Invulnerability', 'Animation',
#        'Super Breath', 'Dimensional Awareness', 'Flight', 'Size Changing',
#        'Teleportation', 'Magic', 'Dimensional Travel',
#        'Molecular Manipulation', 'Energy Manipulation', 'Power Cosmic',
#        'Energy Absorption', 'Elemental Transmogrification',
#        'Fire Resistance', 'Natural Armor', 'Heat Resistance',
#        'Matter Absorption', 'Regeneration', 'Stealth', 'Power Suit',
#        'Energy Blasts', 'Energy Beams', 'Heat Generation', 'Danger Sense',
#        'Phasing', 'Force Fields', 'Hypnokinesis', 'Invisibility',
# ...

# %%
# For Loop for each of every Powers and making them into columns
for col in cols_to_make:
    superpowerdf[col] = superpowerdf["Powers_Split"].str.contains(col, regex = False)
superpowerdf.head()
# Out:
# C:\Users\spart\AppData\Local\Temp\ipykernel_22508\2189540471.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   superpowerdf[col] = superpowerdf["Powers_Split"].str.contains(col, regex = False)
# C:\Users\spart\AppData\Local\Temp\ipykernel_22508\2189540471.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   superpowerdf[col] = superpowerdf["Powers_Split"].str.contains(col, regex = False)
# ...

# %%
superpowerdf = superpowerdf.drop(columns = ["Powers", "Powers_Split"])
superpowerdf
# Out:
#           hero_names  Agility  Super Strength  Stamina  Super Speed  \
# 0            3-D Man     True            True     True         True
# 1             A-Bomb    False            True     True        False
# 2         Abe Sapien     True            True     True        False
# 3           Abin Sur    False           False    False        False
# 4        Abomination    False            True     True         True
# ..               ...      ...             ...      ...          ...
# 662  Yellowjacket II    False           False    False        False
# 663             Ymir    False            True    False        False
# 664             Yoda     True           False     True         True
# 665          Zatanna    False           False    False        False
# 666             Zoom    False           False    False         True
#
#      Accelerated Healing  Durability  Longevity  Camouflage  Self-Sustenance  \
# ...

# %%
# Merging DataFrames
merged_df = pd.merge(superdf, superpowerdf, left_on = "Hero", right_on = "hero_names")
merged_df
# Out:
#      Gender               Race Alignment        Hair color Eye color  \
# 0      Male              Human      good           No Hair    yellow
# 1      Male      Icthyo Sapien      good           No Hair      blue
# 2      Male            Ungaran      good           No Hair      blue
# 3      Male  Human / Radiation       bad           No Hair     green
# 4      Male              Human       bad           No Hair      blue
# ..      ...                ...       ...               ...       ...
# 458    Male              Human      good             Blond      blue
# 459  Female              Human      good  Strawberry Blond      blue
# 460    Male     Yoda's species      good             White     brown
# 461  Female              Human      good             Black      blue
# 462    Male            Unknown       bad             Brown       red
#
#     Skin color             Hero          Publisher    Height    Weight  ...  \
# ...

# %% [markdown]
# # Data Cleaning

# %%
merged_df["Hair color"].value_counts()
# Out:
# Black               127
# Blond                74
# Brown                69
# No Hair              52
# Red                  41
# White                22
# Unknown              18
# Auburn               13
# Green                 6
# Strawberry Blond      5
# Purple                4
# Brown / White         4
# Grey                  4
# black                 3
# blond                 3
# Silver                3
# Blue                  2
# Orange                2
# Pink                  1
# Gold                  1
# Red / White           1
# Indigo                1
# Red / Orange          1
# Red / Grey            1
# Brownn                1
# Yellow                1
# Orange / White        1
# Magenta               1
# Black / Blue          1
# Name: Hair color, dtype: int64

# %%
merged_df["Hair color"]= merged_df["Hair color"].replace("blond", "Blond").replace("black", "Black").replace("Brownn", 
                                                                                                             "Brown")
merged_df["Hair color"].value_counts()
# Out:
# Black               130
# Blond                77
# Brown                70
# No Hair              52
# Red                  41
# White                22
# Unknown              18
# Auburn               13
# Green                 6
# Strawberry Blond      5
# Purple                4
# Brown / White         4
# Grey                  4
# Silver                3
# Blue                  2
# Orange                2
# Pink                  1
# Gold                  1
# Red / White           1
# Indigo                1
# Red / Orange          1
# Red / Grey            1
# Yellow                1
# Orange / White        1
# Magenta               1
# Black / Blue          1
# Name: Hair color, dtype: int64

# %%
merged_df["Height"] = merged_df["Height"].replace(" cm", "", regex = True)
merged_df["Height"]
# Out:
# 0      203.0
# 1      191.0
# 2      185.0
# 3      203.0
# 4      193.0
#        ...
# 458    183.0
# 459    165.0
# 460     66.0
# 461    170.0
# 462    185.0
# Name: Height, Length: 463, dtype: object

# %%
merged_df["Weight"] = merged_df["Weight"].replace(" kg", "", regex = True)
merged_df["Weight"]
# Out:
# 0      441.0
# 1       65.0
# 2       90.0
# 3      441.0
# 4      122.0
#        ...
# 458     83.0
# 459     52.0
# 460     17.0
# 461     57.0
# 462     81.0
# Name: Weight, Length: 463, dtype: object

# %%
merged_df["Weight"] = merged_df["Weight"].astype(float)
merged_df["Height"] = merged_df["Height"].astype(float)

# %%
merged_df.to_csv("SuperPowersDataFrame", index = False)

# %% [markdown]
# # Questions
#
# 1. Compare the average weight of super powers who have Super Speed to those who do not.
#
# 2. What is the average height of heroes for each publisher?

# %% [markdown]
# 1. Compare the average weight of super powers who have Super Speed to those who do not.

# %%
SuperSpeedFilter = merged_df["Super Speed"] == True
SuperSpeed = merged_df[SuperSpeedFilter]
SuperSpeedWeight = SuperSpeed["Weight"].mean()

# %%
NonSuperSpeedFilter = merged_df["Super Speed"] == False
NonSuperSpeed = merged_df[NonSuperSpeedFilter]
NonSuperSpeedWeight = NonSuperSpeed["Weight"].mean()

# %%
print(f"The Average Super Speed Heroes and Non Super Speed Weight. SuperSpeed: {SuperSpeedWeight} NonSuperSpeed: {NonSuperSpeedWeight}")
# Out:
# The Average Super Speed Heroes and Non Super Speed Weight. SuperSpeed: 129.40404040404042 NonSuperSpeed: 101.77358490566037

# %% [markdown]
# 2. What is the average height of heroes for each publisher?

# %%
merged_df.groupby(["Publisher"])["Height"].mean()
# Out:
# Publisher
# DC Comics            181.923913
# Dark Horse Comics    176.909091
# George Lucas         159.600000
# Image Comics         211.000000
# Marvel Comics        191.546128
# Shueisha             171.500000
# Star Trek            181.500000
# Team Epic TV         180.750000
# Unknown              178.000000
# Name: Height, dtype: float64
